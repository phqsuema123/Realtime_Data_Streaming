# %%
import pandas as pd
df=pd.read_csv("users_data.csv")
df.head(10)
# Out:
#                                      id  \
# 0  13ca61cb-0829-45ab-8f95-71735097bb68
# 1  b92b1c07-0d40-43e1-8717-0f0b58828dd8
# 2  4d8aacb8-66bd-4c4f-a20d-100f40b969cb
# 3  7de88265-26b5-4431-b6db-ad7bf2bfa288
# 4  d24f8ca7-55f2-451c-bc11-4bb4445245e7
# 5  9875087e-3bae-4029-b75d-bdb28c3115d6
# 6  ca649b4b-dea4-4501-afec-3cdbd9e05c9e
# 7  4ce31691-0ae8-4213-a996-542b61aa23d6
# 8  19cfcfea-baf0-47e9-884c-06924919e633
# 9  be704b55-39e8-4ea7-b45c-c94a6f6a9772
#
#                                              address  \
# 0  1170 Hærvejen, Frederiksberg, Syddanmark, Denmark
# 1  6306 Calle del Pez, Torrejón de Ardoz, Aragón,...
# 2     8069 Avenida Angola, Acanceh, Coahuila, Mexico
# 3         1759 Bistražinska, Valjevo, Nišava, Serbia
# 4                                                NaN
# 5                                                NaN
# 6  2870 Fatih Sultan Mehmet Cd, Kars, Yozgat, Turkey
# 7  7512 Continuación Mares, Naucalpan de Juárez, ...
# ...

# %%
df.columns
# Out:
# Index(['id', 'address', 'email', 'first_name', 'gender', 'last_name', 'phone',
#        'picture', 'post_code', 'registered_date', 'username'],
#       dtype='object')
